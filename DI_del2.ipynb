# %%
# !pip install nltk

# %%
# Loading af relevante pakker. 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt # For plotting
import seaborn as sns
from tabulate import tabulate

# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

import nltk
nltk.download([
    "names",
    "stopwords",
    "state_union",
    "twitter_samples",
    "movie_reviews",
    "averaged_perceptron_tagger",
    "vader_lexicon",
    "punkt"
])
# Out:
# [nltk_data] Downloading package names to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/NannaBrandt/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ...

# %%
# Importerer bilag 6. 

df_bilag6 = pd.read_excel(r'/Users/NannaBrandt/Downloads/DO2021-main-6/teaching_material/session_11/case/bilag/Bilag_6.xlsx',sheet_name='Medlemmernes Dag besvarelser')

# %%
# Renamer variable
df_bilag6 = df_bilag6.rename(columns={'Spørgsmål 1. Hvordan går det \nhos jer, og hvad optager jer lige nu?': 'spm1','Spørgsmål 2. Har I udfordringer, \nder fylder ekstra meget i øjeblikket?': 'spm2', 'spm1': 'Farvemarkering af hvordan det går','No of Customers': 'farve','Spørgsmål 3: \nHvordan kan vi i DI gøre det endnu bedre for dig og din virksomhed?':'spm3'})

# %%
# Dropper NaN

df_bilag6.dropna()
# Out:
#       Virksom-\nhedsID                                               spm1  \
# 0                    3  Virksomheden er en del af byggebranchen  Ingen...
# 1                    4  Det går rigtig godt, de får mange gode ordre  ...
# 2                    5  Det går godt  Det optager os, om vi kan blive ...
# 3                    6                                      Høj aktivitet
# 4                    7  Går rigtig godt, meget travlt  \nHar en masse ...
# ...                ...                                                ...
# 1500              1670  Udfordringer i 3 mdr  i starten af COVID19 sid...
# 1501              1675   Det er et vikarbureau - de mangler arbejdskraft
# 1502              1676  Vi glæder os til genåbning  Der har været Coro...
# 1503              1682    Forretningen kører lidt trægt og mangler ordrer
# 1505              1697   Hvordan kommer vi tilbage til normal samfund ...
#
#      Farvemarkering af hvordan det går  \
# ...

# %%
# Omdanner vairablen til string
df_bilag6['spm1'] = df_bilag6['spm1'].astype(str)

# %%
df_bilag6['spm1'] = df_bilag6['spm1'].astype(str)
liste = []

for i in df_bilag6['spm1']:
    liste.append(i.lower())

df_bilag6['spm1'] = liste

# %%
liste
# Out:
# ["['virksomheden', 'er', 'en', 'del', 'af', 'byggebranchen', 'ingen', 'coronapåvirkning', 'det', 'går', 'godt', 'virksomheden', 'har', 'travlt', 'eneste', 'udfordring', 'har', 'været', 'et', 'uheldigt', 'sygefravær', 'midt', 'i', 'travlheden']",
#  "['det', 'går', 'rigtig', 'godt', ',', 'de', 'får', 'mange', 'gode', 'ordre', 'så', 'status', 'er', 'god', 'de', 'har', 'ingen', 'syge', 'medarbejder', 'og', 'har', 'heller', 'ikke', 'haft', 'det', 'i', 'forhold', 'til', 'corona']",
#  "['det', 'går', 'godt', 'det', 'optager', 'os', ',', 'om', 'vi', 'kan', 'blive', 'ved', 'med', 'at', 'få', 'ordrer', 'vi', 'har', 'ikke', 'måtte', 'sende', 'folk', 'hjem', ',', 'og', 'vi', 'tjener', 'en', 'smule', 'på', 'det', ',', 'vi', 'laver', 'situationen', 'taget', 'i', 'betragtning', 'kan', 'vi', 'ikke', 'klage']",
#  "['høj', 'aktivitet']",
#  "['går', 'rigtig', 'godt', ',', 'meget', 'travlt', 'har', 'en', 'masse', 'lange', 'projekter']",
# ...

# %%
print(liste["covid"])
print(liste["Covid"])
print(liste["COVID"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-135-b2772695d8f3> in <module>
# ----> 1 print(liste["covid"])
#       2 print(liste["Covid"])
#       3 print(liste["COVID"])
#
# TypeError: list indices must be integers or slices, not str

# %%
# Vores eget forsøg

# Omdanner kolonnen til en liste af ord

df_bilag6['spm1'] = df_bilag6['spm1'].str.replace(r'\?|\.|\'', ' ')
list_of_words = ' '.join(df_bilag6['spm1']).split()

print(list_of_words)
# Out:
# ['Virksomheden', 'er', 'en', 'del', 'af', 'byggebranchen', 'Ingen', 'coronapåvirkning', 'Det', 'går', 'godt', 'Virksomheden', 'har', 'travlt', 'Eneste', 'udfordring', 'har', 'været', 'et', 'uheldigt', 'sygefravær', 'midt', 'i', 'travlheden', 'Det', 'går', 'rigtig', 'godt,', 'de', 'får', 'mange', 'gode', 'ordre', 'Så', 'status', 'er', 'god', 'De', 'har', 'ingen', 'syge', 'medarbejder', 'og', 'har', 'heller', 'ikke', 'haft', 'det', 'i', 'forhold', 'til', 'corona', 'Det', 'går', 'godt', 'Det', 'optager', 'os,', 'om', 'vi', 'kan', 'blive', 'ved', 'med', 'at', 'få', 'ordrer', 'Vi', 'har', 'ikke', 'måtte', 'sende', 'folk', 'hjem,', 'og', 'vi', 'tjener', 'en', 'smule', 'på', 'det,', 'vi', 'laver', 'Situationen', 'taget', 'i', 'betragtning', 'kan', 'vi', 'ikke', 'klage', 'Høj', 'aktivitet', 'Går', 'rigtig', 'godt,', 'meget', 'travlt', 'Har', 'en', 'masse', 'lange', 'projekter', 'Virksomheden', 'er', 'en', 'fremstillingsvirksomhed,', 'og', 'har', 'ikke', 'været', 'sådan', 'vanvittigt', 'hårdt
# ...

# %%
# Vi fjerner stopwords

stopwords = nltk.corpus.stopwords.words('danish')
stopwords
#len(stopwords)
# Out:
# ['og',
#  'i',
#  'jeg',
#  'det',
#  'at',
#  'en',
#  'den',
#  'til',
#  'er',
#  'som',
#  'på',
#  'de',
#  'med',
#  'han',
#  'af',
#  'for',
#  'ikke',
#  'der',
#  'var',
#  'mig',
#  'sig',
#  'men',
#  'et',
#  'har',
#  'om',
#  'vi',
#  'min',
#  'havde',
#  'ham',
#  'hun',
#  'nu',
#  'over',
#  'da',
#  'fra',
#  'du',
#  'ud',
#  'sin',
#  'dem',
#  'os',
#  'op',
#  'man',
#  'hans',
#  'hvor',
#  'eller',
#  'hvad',
#  'skal',
#  'selv',
#  'her',
#  'alle',
#  'vil',
#  'blev',
#  'kunne',
#  'ind',
#  'når',
#  'være',
#  'dog',
#  'noget',
#  'ville',
#  'jo',
#  'deres',
#  'efter',
#  'ned',
#  'skulle',
#  'denne',
#  'end',
#  'dette',
#  'mit',
#  'også',
#  'under',
#  'have',
#  'dig',
#  'anden',
#  'hende',
#  'mine',
#  'alt',
#  'meget',
#  'sit',
#  'sine',
#  'vor',
#  'mod',
#  'disse',
#  'hvis',
#  'din',
#  'nogle',
#  'hos',
#  'blive',
#  'mange',
#  'ad',
#  'bliver',
#  'hendes',
#  'været',
#  'thi',
#  'jer',
#  'sådan']

# %%
# Fjerner stopwords 

list_of_words = [w for w in list_of_words if w.lower() not in stopwords]

print(len(list_of_words))
# Out:
# 24609

# %%
# Finder mest nævnte ord

from nltk.tokenize import sent_tokenize

# %%
fd = nltk.FreqDist(list_of_words)
print(fd)
# Out:
# <FreqDist with 7131 samples and 24609 outcomes>

# %%
fd.most_common(3)
# Out:
# [('går', 666), ('-', 553), ('godt', 477)]

# %%
# Opdele teksten (forøsger at anvende nltk-pakken)

nltk.word_tokenize(list_of_words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-54261ef32e7c> in <module>
#       1 # Opdele teksten
#       2
# ----> 3 nltk.word_tokenize(list_of_words)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     128     :type preserve_line: bool
#     129     """
# --> 130     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     131     return [
#     132         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     106     """
#     107     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 108     return tokenizer.tokenize(text)
#     109
#     110
#
# ...

# %%
# Gamelt forsøg

spm1_corpus = df_bilag6['spm1'].tolist()
# Out:
#   File "<ipython-input-108-e431b0050522>", line 4
#     list_of_words_low.append(i.lower())
#     ^
# IndentationError: expected an indented block

# %%
spm1_corpus
# Out:
# ['Virksomheden er en del af byggebranchen. Ingen coronapåvirkning. Det går godt. Virksomheden har travlt. Eneste udfordring har været et uheldigt sygefravær midt i travlheden.',
#  'Det går rigtig godt, de får mange gode ordre. Så status er god. \nDe har ingen syge medarbejder og har heller ikke haft det i forhold til corona.',
#  'Det går godt. Det optager os, om vi kan blive ved med at få ordrer. Vi har ikke måtte sende folk hjem, og vi tjener en smule på det, vi laver. Situationen taget i betragtning kan vi ikke klage.',
#  'Høj aktivitet',
#  'Går rigtig godt, meget travlt. \nHar en masse lange projekter. ',
# ...

# %%
word_tokenize(spm1_corpus, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-ca062ffe0595> in <module>
# ----> 1 word_tokenize(spm1_corpus, 1)
#
# NameError: name 'word_tokenize' is not defined
